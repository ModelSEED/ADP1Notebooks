# %% [markdown]
# # ADP1 Expression-Constrained Flux Analysis
#
# ## Objectives
#
# This notebook performs expression-constrained flux balance analysis on 8 ADP1 strains using proteomics data. For each strain, we analyze flux profiles both with and without the DGOA enzyme pathway.
#
# ### Analysis Goals:
# 1. Generate predicted flux profiles for all 8 strains (16 conditions total: 8 strains × 2 DGOA variants)
# 2. Validate that all solutions are biologically feasible
# 3. Export results in multiple formats (JSON, Excel, Escher maps)
# 4. Compare metabolic differences between strains and DGOA conditions
#
# ### Strains:
# - **ACN2586**: Initial construct with dgoA* and native DAHP synthesis deleted
# - **ACN2821**: Evolved strain with single copy of dgoA*
# - **ACN3015**: Single copy of dgoA after evolution
# - **ACN3468**: Multiple copies of dgoA*
# - **ACN3471**: Multiple copies of dgoA
# - **ACN3474**: Multiple copies of dgoA, partially evolved
# - **ACN3477**: Multiple copies of dgoA, more evolved
# - **ADP1**: Wild-type Acinetobacter baylyi ADP1

# %% [markdown]
# ## Run Expression Flux Analysis Pipeline
#
# This step:
# 1. Loads the metabolic model and media
# 2. Loads proteomics data and averages replicates
# 3. Processes all 16 conditions (8 strains × 2 DGOA variants)
# 4. Caches intermediate results

# %%
# %run util.py
#Loading expression data and averaging replicates
raw_expression = MSExpression.from_spreadsheet(
    filename="data/ASCR_UGA_Proteomics_DgoA_add_strains_2025_pyruvate.xlsx",
    sheet_name="Imputed",
    skiprows=0,
    type="Log2",
    id_column="ACIAD"
)
#Averaging replicates
strains = ["Pyruvate_ACN2586_DgoA_2025", "Pyruvate_ACN2821_DgoA_2025", "Pyruvate_ACN3425_DgoA_2025", "Pyruvate_ACN3427_DgoA_2025","Pyruvate_ACN3429_DgoA_2025", "Pyruvate_ACN3430_DgoA_2025", "Pyruvate_ADP1_DgoA_2025"]
util.save("strains",strains)
averaged_expression = raw_expression.average_expression_replicates(strains)
util.save("averaged_expression_data", averaged_expression._data.to_dict())
#Transforming data
transformed_expression = averaged_expression.translate_data("RelativeAbundance")
util.save("transformed_expression_data", transformed_expression._data.to_dict())
#Translating to reaction data
model = MSModelUtil.from_cobrapy("data/FullyTranslatedPublishedModel.json")
reaction_expression = transformed_expression.build_reaction_expression(model.model)
util.save("reaction_expression_data", reaction_expression._data.to_dict())
# Out:
# /Users/chenry/Dropbox/Projects/KBUtilLib/src
# 2025-11-14 12:28:09,785 - __main__.NotebookUtil - INFO - Loaded 0 tokens from /Users/chenry/.tokens
# 2025-11-14 12:28:09,785 - __main__.NotebookUtil - INFO - Loaded kbase tokens from /Users/chenry/.kbase/token
# 2025-11-14 12:28:09,786 - __main__.NotebookUtil - WARNING - Section 'ModelSEEDBiochem' not found in config
# modelseedpy 0.4.2
# cobrakbase 0.4.0
# 2025-11-14 12:28:14,011 - __main__.NotebookUtil - INFO - ModelSEED database loaded from /Users/chenry/Dropbox/Projects/KBUtilLib/src/kbutillib/dependencies/ModelSEEDDatabase
# 2025-11-14 12:28:14,502 - __main__.NotebookUtil - WARNING - BLAST tools not found. Install NCBI BLAST+ to use BLAST functionality. On Ubuntu/Debian: sudo apt-get install ncbi-blast+, On MacOS: brew install blast
# 2025-11-14 12:28:14,503 - __main__.NotebookUtil - INFO - Notebook environment detected
# 2025-11-14 12:28:14,503 - __main__.NotebookUtil - INFO - ArgoGatewayClient initialised | model=gpto3mini env=dev timeout=120.0s url=https://apps-dev.inside.anl.gov/argoapi/api/v1/resource/streamchat/
# /opt/anaconda3/envs/modelseed/lib/python3.9/site-packages/openpyxl/worksheet/_reader.py:329: UserWarning: Conditional Formatting extension is not supported and will be removed
#   warn(msg)

# %%
results = {}
models_dict = {}
model.model.reactions.get_by_id("rxn01332_c0").lower_bound = 0
model.model.reactions.get_by_id("rxn01332_c0").upper_bound = 0
model.model.reactions.get_by_id("rxn00595_c0").lower_bound = 0
model.model.reactions.get_by_id("rxn00595_c0").upper_bound = 0
model.model.reactions.get_by_id("rxn00966_c0").lower_bound = 0
model.model.reactions.get_by_id("rxn00966_c0").upper_bound = 0
model.model.reactions.get_by_id("rxn12374_c0").lower_bound = 0
model.model.reactions.get_by_id("rxn12374_c0").upper_bound = 0
model.model.reactions.get_by_id("rxn12199_c0").lower_bound = 0
model.model.reactions.get_by_id("rxn12199_c0").upper_bound = 0
model.model.reactions.get_by_id("rxn12363_c0").lower_bound = 0
model.model.reactions.get_by_id("rxn12363_c0").upper_bound = 0
pyruvate_media = util.get_media("KBaseMedia/Carbon-Pyruvic-Acid")
solution = util.run_fba(model,media=pyruvate_media,objective="GROWTH_DASH_RXN",run_pfba=True)

# Constrain biomass to specified fraction of optimal
util.constrain_objective_to_fraction_of_optimum(
    model,
    objective="GROWTH_DASH_RXN",
    fraction=0.25
)
for i, strain in enumerate(strains, 1):
    model.util = util
    # Fit model flux to expression data
    analysis_result = reaction_expression.fit_model_flux_to_data(
        model=model,
        condition=strain,
        default_coef=0.01,
        activation_threshold=None,
        deactivation_threshold=0.00001
    )

    # Extract off_off list (reactions to be deactivated)
    off_off_list = analysis_result.get("off_off", [])

    # Extract on_on list (reactions to be activated)
    off_on_list = analysis_result.get("off_on", [])

    # Apply deactivation constraints
    for rxn_id in off_off_list:
        try:
            rxn = model_copy.model.reactions.get_by_id(rxn_id)
            rxn.lower_bound = 0
            rxn.upper_bound = 0
        except:
            # Reaction might not exist in model
            pass

    new_solution = util.run_fba(model,media=pyruvate_media,objective="GROWTH_DASH_RXN",run_pfba=True)   
    
    # Extract fluxes (only non-zero)
    fluxes = {}
    for rxn in model.model.reactions:
        if abs(new_solution.fluxes[rxn.id]) > 1e-9:
            fluxes[rxn.id] = new_solution.fluxes[rxn.id]
    dgoa_flux = new_solution.fluxes["DgoA"]
    biomass = new_solution.fluxes.get("GROWTH_DASH_RXN", 0)

    results[strain] = {
        "fluxes": fluxes,
        "biomass": biomass,
        "active_reactions": len(fluxes),
        "off_off_reactions": off_off_list,
        "off_on_reactions": off_on_list,
        "dgoa_flux": dgoa_flux,
        "solution_status": new_solution.status
    }

util.save("ADP1ExpressionAnalysis",results)
# Out:
# INFO:modelseedpy.core.msmodelutl:cpd00063 not found in model!
# INFO:modelseedpy.core.msmodelutl:cpd10516 not found in model!
# INFO:modelseedpy.core.msmodelutl:cpd00205 not found in model!
# INFO:modelseedpy.core.msmodelutl:cpd00254 not found in model!
# INFO:modelseedpy.core.msmodelutl:cpd00099 not found in model!
# INFO:modelseedpy.core.msmodelutl:cpd00058 not found in model!
# INFO:modelseedpy.core.msmodelutl:cpd00030 not found in model!
# INFO:modelseedpy.core.msmodelutl:cpd00034 not found in model!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn12353_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_CPD_DASH_592_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn06556_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_GUANOSINE_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_GLY_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn00062_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_CPD_DASH_335_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_HOMO_DASH_SER_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_GLC_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_FUM_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn19256_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_ASN_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_XANTHINE_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn02066_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn01781_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_D_DASH_GALACTARATE_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn08625_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_D_DASH_ALANINE_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_TRP_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_PYRUVATE_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_NITRATE_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn12408_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn12404_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_MAL_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn12320_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn12384_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_SUBERATE_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_ARG_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn12350_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_BETAINE_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn08030_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_CHOLINE_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_D_DASH_LACTATE_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_CONIFERYL_DASH_ALDEHYDE_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn03393_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_CARBON_DASH_DIOXIDE_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn12307_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_4_DASH_HYDROXYBENZOATE_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_DEOXYADENOSINE_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn08434_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn12358_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_CPDIM_DASH_6112_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_CHLOROGENATE_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature TRIACYLGLYCEROL_W_DASH_RXN not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_DEOXYINOSINE_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_CAFFEATE_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_HOMOSERINE_DASH_LACTONE_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_C10_COLON_0_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn02160_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn12361_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn05039_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_2_DASH_KETOGLUTARATE_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_OXYGEN_DASH_MOLECULE_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_C6_COLON_0_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_4_DASH_HYDROXY_DASH_BENZYL_DASH_ALCOHOL_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn05467_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_NA_PLUS__LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_TYR_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn12340_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn12360_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_INOSINE_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn05220_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn12343_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn12401_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_SHIKIMATE_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_FORMATE_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn12342_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_WATER_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn08428_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn12305_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_QUINATE_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_CPDIM_DASH_6114_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_CPD_DASH_110_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_C6_COLON_2_LPAREN_C2_COMMA_C4_RPAREN__LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_MALONATE_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_SO3_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_ETHANESULFONATE_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_DEOXYGUANOSINE_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_D_DASH_GLUCARATE_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_L_DASH_ASPARTATE_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn08795_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn05468_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_ADENOSINE_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn08063_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn12304_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_CPD_DASH_148_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn05581_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn12349_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn12383_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn11322_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_CIS_DASH_CIS_DASH_MUCONATE_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_CPDIM_DASH_6115_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn12306_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_ACET_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_3_DASH_KETOBUTYRATE_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn08653_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn12335_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn09172_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn09218_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_NITRITE_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_LYS_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn06033_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_SUC_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_C8_COLON_0_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_TAURINE_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_VANILLATE_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature UNBAL_DASH_PROTON not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_ADIPATE_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_GLT_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_GLYCOLLATE_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_URIDINE_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_SULFATE_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_THR_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn05319_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn12328_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_UREA_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_ETOH_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_THYMIDINE_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn12351_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_C12_COLON_0_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_CPD_DASH_6501_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn06138_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn03173_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn12344_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn08610_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn00086_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_TOLUENE_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_PHE_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_BUTANEDIOL_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_PURINE_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_FE_PLUS_2_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_URACIL_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_L_DASH_ALPHA_DASH_ALANINE_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_C16_COLON_0_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_4_DASH_AMINO_DASH_BUTYRATE_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature UNBAL_DASH_S_DASH_ADENOSYL_DASH_4_DASH_METHYLTHIO_DASH_2_DASH_OXOBUTANOATE not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_COUMARATE_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn12402_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_ETHANOL_DASH_AMINE_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_NICOTINAMIDE_NUCLEOTIDE_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_CYTOSINE_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_ANTHRANILATE_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn12376_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_L_DASH_ORNITHINE_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_BUTYRIC_ACID_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn12411_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn12412_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn12409_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn10126_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn12199_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn12496_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_FRU_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_CPDIM_DASH_6116_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_D_DASH_SERINE_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_CPD_DASH_302_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_AMMONIUM_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_GLUCONATE_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn12192_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_MET_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_CPD_DASH_205_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_DEOXYURIDINE_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_CIT_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn12407_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn12355_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn12330_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn12338_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_GLN_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn12410_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature GROWTH_DASH_RXN not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_C18_COLON_1_LPAREN_C9_RPAREN__LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_CPD_DASH_3623_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn12331_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn12308_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_CYTIDINE_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_PI_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_CPD_DASH_218_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_GLYCEROL_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_CPD_DASH_3571_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_L_DASH_LACTATE_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn03168_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn08184_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn09260_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_PRO_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_GLUTARATE_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn12323_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_C14_COLON_0_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_BENZOATE_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn12219_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_CARNITINE_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_C18_COLON_0_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_BENZYL_DASH_ALCOHOL_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_C16_COLON_1_LPAREN_C7_RPAREN__LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_C5_COLON_0_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_PROPIONATE_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_DEOXYCYTIDINE_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn05667_c0 not found in expression object!
# INFO:modelseedpy.core.msmodelutl:cpd00063 not found in model!
# INFO:modelseedpy.core.msmodelutl:cpd10516 not found in model!
# INFO:modelseedpy.core.msmodelutl:cpd00205 not found in model!
# INFO:modelseedpy.core.msmodelutl:cpd00254 not found in model!
# INFO:modelseedpy.core.msmodelutl:cpd00099 not found in model!
# INFO:modelseedpy.core.msmodelutl:cpd00058 not found in model!
# INFO:modelseedpy.core.msmodelutl:cpd00030 not found in model!
# INFO:modelseedpy.core.msmodelutl:cpd00034 not found in model!
# On: {}
# Off: {'rxn03887_c0': 0.8933674222059408, 'rxn00990_c0': 0.9147331776101639, 'rxn01299_c0': 0.6973454881289313, 'rxn00327_c0': 0.5346019040157056, 'rxn03908_c0': 0.7178840646917763, 'rxn08783_c0': 0.933221657304459, 'rxn00470_c0': 0.9524091566771169, 'rxn12397_c0': 0.442841250950782, 'rxn01015_c0': 0.5172297676750564, 'rxn02296_c0': 0.38318482481009974, 'rxn02971_c0': 0.04184855110293412, 'rxn00101_c0': 0.13530360020315513, 'rxn05552_c0': 0.83334070045295, 'rxn12332_c0': 0.6812945329813767, 'rxn01368_c0': 0.233019394315495, 'rxn19072_c0': 0.6973454881289313, 'rxn05172_c0': 0.600449681232318, 'rxn00500_c0': 0.933221657304459, 'rxn12262_c0': 0.9173916865889098, 'rxn00966_c0': 0.8815212574144073, 'rxn03130_c0': 0.68204211234313, 'rxn12363_c0': 0.2814900156963053, 'rxn01545_c0': 0.6973454881289313, 'CYT_DASH_UBIQUINOL_DASH_OXID_DASH_D_DASH_RXN': 0.3017225414300364, 'rxn12450_c0': 0.6470425970101281, 'rxn12433_c0': 0.442841250950782, 'TRANS_DASH_RXNIM_DASH_5771': 0.600449681232318, 'rxn02927_c0': 0.5325806831696126, 'rxn00872_c0': 0.9349219853965772, 'rxn09167_c0': 0.6699105466827832, 'rxn12263_c0': 0.9173916865889098, 'rxn05602_c0': 0.2835351096330623, 'rxn05470_c0': 0.2835351096330623, 'rxn01226_c0': 0.6973454881289313, 'rxn12371_c0': 0.8974134789692206, 'rxn03893_c0': 0.9037498166348272, 'rxn03004_c0': 0.20033418852999818, 'rxn12233_c0': 0.7518188397842885, 'rxn00002_c0': 0.7301357377942229, 'rxn00875_c0': 0.9147331776101639, 'rxn09310_c0': 0.33663491269457535, 'rxn01365_c0': 0.9335117332735275, 'rxn00533_c0': 0.21248017701421962, 'rxn00584_c0': 0.632693041517291, 'rxn12400_c0': 0.442841250950782, 'rxn05298_c0': 0.5966652266328308, 'rxn02782_c0': 0.8073045374965193, 'rxn00938_c0': 0.5440757971141335, 'rxn05215_c0': 0.5759061467956502, 'rxn12374_c0': 0.8276620101578317, 'TRANS_DASH_RXN_DASH_201': 0.418731427147233, 'rxn12297_c0': 0.14065525583336813, 'rxn01204_c0': 0.3054534375058281, 'rxn02504_c0': 0.1895043526466871, 'rxn03904_c0': 0.4015253801605997, 'rxn03586_c0': 0.7170785406379154, 'rxn00433_c0': 0.6478069931505701, 'rxn03422_c0': 0.757260735735218, 'rxn02508_c0': 0.13407932774520928, 'rxn26065_c0': 0.6973454881289313, 'RXN0_DASH_366': 0.6973454881289313, 'rxn08975_c0': 0.5673977405057116, 'rxn12228_c0': 0.5783993321191707, 'rxn09256_c0': 0.8276620101578317, 'rxn00601_c0': 0.9247291513868894, 'rxn01634_c0': 0.9108100548536966, 'rxn12254_c0': 0.9173916865889098, 'rxn00962_c0': 0.5832726263601402, 'rxn12498_c0': 0.6171254461152376, 'rxn01802_c0': 0.31853066158801296, 'rxn12366_c0': 0.2835351096330623, 'rxn12399_c0': 0.442841250950782, 'rxn12231_c0': 0.48791555024860267, 'rxn05466_c0': 0.8191610835994405, 'rxn03897_c0': 0.6289462507958478, 'rxn04753_c0': 0.9173916865889098, 'rxn01257_c0': 0.8712226699040198, 'rxn02503_c0': 0.7311541927323592}
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn12353_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_CPD_DASH_592_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn06556_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_GUANOSINE_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_GLY_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn00062_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_CPD_DASH_335_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_HOMO_DASH_SER_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_GLC_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_FUM_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn19256_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_ASN_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_XANTHINE_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn02066_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn01781_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_D_DASH_GALACTARATE_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn08625_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_D_DASH_ALANINE_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_TRP_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_PYRUVATE_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_NITRATE_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn12408_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn12404_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_MAL_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn12320_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn12384_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_SUBERATE_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_ARG_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn12350_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_BETAINE_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn08030_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_CHOLINE_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_D_DASH_LACTATE_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_CONIFERYL_DASH_ALDEHYDE_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn03393_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_CARBON_DASH_DIOXIDE_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn12307_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_4_DASH_HYDROXYBENZOATE_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_DEOXYADENOSINE_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn08434_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn12358_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_CPDIM_DASH_6112_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_CHLOROGENATE_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature TRIACYLGLYCEROL_W_DASH_RXN not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_DEOXYINOSINE_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_CAFFEATE_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_HOMOSERINE_DASH_LACTONE_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_C10_COLON_0_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn02160_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn12361_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn05039_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_2_DASH_KETOGLUTARATE_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_OXYGEN_DASH_MOLECULE_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_C6_COLON_0_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_4_DASH_HYDROXY_DASH_BENZYL_DASH_ALCOHOL_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn05467_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_NA_PLUS__LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_TYR_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn12340_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn12360_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_INOSINE_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn05220_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn12343_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn12401_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_SHIKIMATE_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_FORMATE_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn12342_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_WATER_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn08428_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn12305_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_QUINATE_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_CPDIM_DASH_6114_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_CPD_DASH_110_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_C6_COLON_2_LPAREN_C2_COMMA_C4_RPAREN__LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_MALONATE_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_SO3_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_ETHANESULFONATE_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_DEOXYGUANOSINE_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_D_DASH_GLUCARATE_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_L_DASH_ASPARTATE_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn08795_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn05468_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_ADENOSINE_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn08063_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn12304_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_CPD_DASH_148_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn05581_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn12349_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn12383_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn11322_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_CIS_DASH_CIS_DASH_MUCONATE_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_CPDIM_DASH_6115_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn12306_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_ACET_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_3_DASH_KETOBUTYRATE_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn08653_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn12335_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn09172_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn09218_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_NITRITE_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_LYS_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn06033_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_SUC_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_C8_COLON_0_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_TAURINE_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_VANILLATE_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature UNBAL_DASH_PROTON not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_ADIPATE_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_GLT_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_GLYCOLLATE_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_URIDINE_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_SULFATE_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_THR_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn05319_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn12328_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_UREA_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_ETOH_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_THYMIDINE_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn12351_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_C12_COLON_0_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_CPD_DASH_6501_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn06138_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn03173_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn12344_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn08610_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn00086_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_TOLUENE_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_PHE_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_BUTANEDIOL_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_PURINE_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_FE_PLUS_2_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_URACIL_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_L_DASH_ALPHA_DASH_ALANINE_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_C16_COLON_0_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_4_DASH_AMINO_DASH_BUTYRATE_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature UNBAL_DASH_S_DASH_ADENOSYL_DASH_4_DASH_METHYLTHIO_DASH_2_DASH_OXOBUTANOATE not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_COUMARATE_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn12402_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_ETHANOL_DASH_AMINE_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_NICOTINAMIDE_NUCLEOTIDE_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_CYTOSINE_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_ANTHRANILATE_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn12376_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_L_DASH_ORNITHINE_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_BUTYRIC_ACID_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn12411_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn12412_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn12409_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn10126_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn12199_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn12496_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_FRU_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_CPDIM_DASH_6116_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_D_DASH_SERINE_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_CPD_DASH_302_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_AMMONIUM_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_GLUCONATE_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn12192_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_MET_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_CPD_DASH_205_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_DEOXYURIDINE_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_CIT_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn12407_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn12355_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn12330_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn12338_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_GLN_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# ...
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn12306_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_ACET_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_3_DASH_KETOBUTYRATE_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn08653_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn12335_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn09172_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn09218_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_NITRITE_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_LYS_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn06033_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_SUC_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_C8_COLON_0_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_TAURINE_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_VANILLATE_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature UNBAL_DASH_PROTON not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_ADIPATE_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_GLT_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_GLYCOLLATE_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_URIDINE_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_SULFATE_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_THR_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn05319_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn12328_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_UREA_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_ETOH_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_THYMIDINE_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn12351_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_C12_COLON_0_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_CPD_DASH_6501_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn06138_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn03173_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn12344_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn08610_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn00086_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_TOLUENE_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_PHE_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_BUTANEDIOL_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_PURINE_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_FE_PLUS_2_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_URACIL_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_L_DASH_ALPHA_DASH_ALANINE_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_C16_COLON_0_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_4_DASH_AMINO_DASH_BUTYRATE_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature UNBAL_DASH_S_DASH_ADENOSYL_DASH_4_DASH_METHYLTHIO_DASH_2_DASH_OXOBUTANOATE not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_COUMARATE_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn12402_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_ETHANOL_DASH_AMINE_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_NICOTINAMIDE_NUCLEOTIDE_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_CYTOSINE_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_ANTHRANILATE_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn12376_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_L_DASH_ORNITHINE_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_BUTYRIC_ACID_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn12411_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn12412_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn12409_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn10126_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn12199_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn12496_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_FRU_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_CPDIM_DASH_6116_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_D_DASH_SERINE_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_CPD_DASH_302_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_AMMONIUM_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_GLUCONATE_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn12192_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_MET_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_CPD_DASH_205_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_DEOXYURIDINE_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_CIT_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn12407_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn12355_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn12330_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn12338_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_GLN_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn12410_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature GROWTH_DASH_RXN not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_C18_COLON_1_LPAREN_C9_RPAREN__LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_CPD_DASH_3623_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn12331_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn12308_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_CYTIDINE_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_PI_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_CPD_DASH_218_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_GLYCEROL_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_CPD_DASH_3571_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_L_DASH_LACTATE_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn03168_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn08184_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn09260_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_PRO_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_GLUTARATE_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn12323_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_C14_COLON_0_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_BENZOATE_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn12219_c0 not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_CARNITINE_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_C18_COLON_0_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_BENZYL_DASH_ALCOHOL_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_C16_COLON_1_LPAREN_C7_RPAREN__LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_C5_COLON_0_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_PROPIONATE_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature EXF_DASH_DEOXYCYTIDINE_LBRACKET_Extraorganism_RBRACKET_ not found in expression object!
# WARNING:modelseedpy.multiomics.msexpression:Feature rxn05667_c0 not found in expression object!
# INFO:modelseedpy.core.msmodelutl:cpd00063 not found in model!
# INFO:modelseedpy.core.msmodelutl:cpd10516 not found in model!
# INFO:modelseedpy.core.msmodelutl:cpd00205 not found in model!
# INFO:modelseedpy.core.msmodelutl:cpd00254 not found in model!
# INFO:modelseedpy.core.msmodelutl:cpd00099 not found in model!
# INFO:modelseedpy.core.msmodelutl:cpd00058 not found in model!
# INFO:modelseedpy.core.msmodelutl:cpd00030 not found in model!
# INFO:modelseedpy.core.msmodelutl:cpd00034 not found in model!
# On: {}
# Off: {'rxn00990_c0': 0.8518682334921533, 'rxn01299_c0': 0.15974344666495485, 'rxn00327_c0': 0.7738243106099235, 'rxn03908_c0': 0.7330483247385104, 'rxn20547_c0': 0.18566345912020712, 'rxn08783_c0': 0.9300960054676595, 'rxn12364_c0': 0.16744011751078647, 'rxn00470_c0': 0.9514578278025722, 'rxn01015_c0': 0.0006165929287904392, 'rxn02296_c0': 0.016734150504007245, 'rxn02971_c0': 0.2589926049271115, 'rxn00101_c0': 0.15339558928214386, 'rxn05552_c0': 0.9106322538912686, 'rxn12332_c0': 0.7289934355114208, 'rxn03159_c0': 0.265648485894674, 'rxn19072_c0': 0.15974344666495485, 'rxn05172_c0': 0.8081906315467818, 'rxn00500_c0': 0.9300960054676595, 'rxn12262_c0': 0.5029278131562755, 'rxn00966_c0': 0.9069180467959839, 'rxn03130_c0': 0.6187816730165618, 'rxn01545_c0': 0.15974344666495485, 'rxn12450_c0': 0.7058757349270752, 'TRANS_DASH_RXNIM_DASH_5771': 0.8081906315467818, 'rxn02927_c0': 0.5689355940020657, 'rxn00872_c0': 0.9525109557321149, 'rxn09167_c0': 0.4190278780896897, 'rxn12263_c0': 0.5029278131562755, 'rxn09188_c0': 0.36151884367619447, 'rxn05602_c0': 0.09037377518447151, 'rxn05470_c0': 0.09037377518447151, 'rxn01226_c0': 0.15974344666495485, 'rxn12371_c0': 0.7888942118149095, 'rxn03893_c0': 0.6086377920707121, 'rxn03004_c0': 0.8372285328274738, 'rxn12233_c0': 0.6169508923048177, 'rxn00002_c0': 0.06123118491682098, 'rxn00875_c0': 0.8518682334921533, 'rxn09310_c0': 0.27000648760854873, 'rxn01365_c0': 0.938326340975467, 'rxn05579_c0': 0.16744011751078647, 'rxn00533_c0': 0.03968700319762247, 'rxn00584_c0': 0.5167577011032569, 'rxn05298_c0': 0.13113491282935494, 'rxn02782_c0': 0.7540633494673097, 'rxn00938_c0': 0.4609679422339151, 'rxn05215_c0': 0.39780230735500394, 'rxn12374_c0': 0.4972455780835088, 'TRANS_DASH_RXN_DASH_201': 0.3405128628081598, 'rxn12297_c0': 0.230803455714924, 'rxn02504_c0': 0.05256848811565185, 'rxn05221_c0': 0.22670577075263307, 'rxn03904_c0': 0.3318270602301442, 'rxn00433_c0': 0.6550148144455871, 'rxn02508_c0': 0.24967620904370788, 'rxn26065_c0': 0.15974344666495485, 'RXN0_DASH_366': 0.15974344666495485, 'rxn08975_c0': 0.5025769934029286, 'rxn12228_c0': 0.5979711318120475, 'rxn09256_c0': 0.4972455780835088, 'rxn00601_c0': 0.9197646833413946, 'rxn01634_c0': 0.8156652566916063, 'rxn12254_c0': 0.5029278131562755, 'rxn00095_c0': 0.010100167396786897, 'rxn12498_c0': 0.5406937591977227, 'rxn12366_c0': 0.09037377518447151, 'rxn12231_c0': 0.14766590839561186, 'rxn05466_c0': 0.9112671050313468, 'rxn03897_c0': 0.5108906618932413, 'rxn04753_c0': 0.5029278131562755, 'rxn00504_c0': 0.36151884367619447, 'rxn06043_c0': 0.1967280720346269, 'rxn01257_c0': 0.6797369276851338, 'rxn02503_c0': 0.8250757379084721}

# %% [markdown]
# # Fitting fluxes to fold change data

# %%
# %run util.py
from modelseedpy.fbapkg.fluxfittingpkg import FluxFittingPkg

# Load the uplist and downlist
with open("data/uplist.txt", "r") as f:
    uplist = [line.strip() for line in f if line.strip()]

with open("data/downlist.txt", "r") as f:
    downlist = [line.strip() for line in f if line.strip()]

print(f"Loaded {len(uplist)} genes in uplist")
print(f"Loaded {len(downlist)} genes in downlist")

# Load the existing results
results = util.load("ADP1ExpressionAnalysis")
strains = util.load("strains")

# Load the model
model = MSModelUtil.from_cobrapy("data/FullyTranslatedPublishedModel.json")

# Build a mapping from genes to reactions
gene_to_reactions = {}
for rxn in model.model.reactions:
    for gene in rxn.genes:
        gene_id = str(gene.id)
        if gene_id not in gene_to_reactions:
            gene_to_reactions[gene_id] = []
        gene_to_reactions[gene_id].append(rxn.id)

print(f"Built gene-to-reaction mapping for {len(gene_to_reactions)} genes")

# For each strain, create targetflux and run flux fitting
for strain in strains:
    print(f"\nProcessing {strain}...")
    
    if strain not in results:
        print(f"  WARNING: {strain} not found in results, skipping")
        continue
    
    # Get original fluxes
    original_fluxes = results[strain]["fluxes"]
    
    # Create targetflux by modifying fluxes based on gene lists
    targetflux = {}
    modified_count = {"up": 0, "down": 0, "unchanged": 0}
    
    for rxn_id, flux_value in original_fluxes.items():
        # Check if this reaction is associated with uplist or downlist genes
        rxn_genes = []
        if rxn_id in model.model.reactions:
            rxn = model.model.reactions.get_by_id(rxn_id)
            rxn_genes = [str(g.id) for g in rxn.genes]
        
        # Determine if reaction should be modified
        is_upregulated = any(gene in uplist for gene in rxn_genes)
        is_downregulated = any(gene in downlist for gene in rxn_genes)
        
        if is_upregulated:
            targetflux[rxn_id] = flux_value * 2.0
            modified_count["up"] += 1
        elif is_downregulated:
            targetflux[rxn_id] = flux_value / 2.0
            modified_count["down"] += 1
        else:
            targetflux[rxn_id] = flux_value
            modified_count["unchanged"] += 1
    
    # Store targetflux in results
    results[strain]["targetflux"] = targetflux
    
    print(f"  Created targetflux: {modified_count['up']} up, {modified_count['down']} down, {modified_count['unchanged']} unchanged")
    
    # Create a fresh model copy for flux fitting
    import cobra.io
    model_copy = MSModelUtil.from_cobrapy(cobra.io.json.to_json(model.model))
    
    # Apply same constraints as original simulation
    model_copy.model.reactions.get_by_id("rxn01332_c0").lower_bound = 0
    model_copy.model.reactions.get_by_id("rxn01332_c0").upper_bound = 0
    model_copy.model.reactions.get_by_id("rxn00595_c0").lower_bound = 0
    model_copy.model.reactions.get_by_id("rxn00595_c0").upper_bound = 0
    model_copy.model.reactions.get_by_id("rxn00966_c0").lower_bound = 0
    model_copy.model.reactions.get_by_id("rxn00966_c0").upper_bound = 0
    model_copy.model.reactions.get_by_id("rxn12374_c0").lower_bound = 0
    model_copy.model.reactions.get_by_id("rxn12374_c0").upper_bound = 0
    model_copy.model.reactions.get_by_id("rxn12199_c0").lower_bound = 0
    model_copy.model.reactions.get_by_id("rxn12199_c0").upper_bound = 0
    model_copy.model.reactions.get_by_id("rxn12363_c0").lower_bound = 0
    model_copy.model.reactions.get_by_id("rxn12363_c0").upper_bound = 0
    
    # Relax growth constraints (remove biomass fraction constraint)
    biomass_rxn = model_copy.model.reactions.get_by_id("GROWTH_DASH_RXN")
    biomass_rxn.lower_bound = 0  # Allow any positive growth
    
    # Set up media
    pyruvate_media = util.get_media("KBaseMedia/Carbon-Pyruvic-Acid")
    util._set_model_media(model_copy, pyruvate_media)
    
    # Use FluxFittingPkg to fit to targetflux
    try:
        # Get package manager
        if not hasattr(model_copy, 'pkgmgr'):
            from modelseedpy import MSPackageManager
            model_copy.pkgmgr = MSPackageManager.get_pkg_mgr(model_copy.model)
        
        # Build flux fitting package
        ffpkg = model_copy.pkgmgr.getpkg("FluxFittingPkg")
        ffpkg.build_package({
            "target_flux": targetflux,
            "set_objective": 1
        })
        
        # Optimize
        solution = model_copy.model.optimize()
        
        if solution.status == "optimal":
            # Extract new fluxes
            newfluxes = {}
            for rxn in model_copy.model.reactions:
                if abs(solution.fluxes[rxn.id]) > 1e-9:
                    newfluxes[rxn.id] = solution.fluxes[rxn.id]
            
            results[strain]["newfluxes"] = newfluxes
            results[strain]["newflux_biomass"] = solution.fluxes.get("GROWTH_DASH_RXN", 0)
            results[strain]["newflux_status"] = solution.status
            
            print(f"  ✓ Flux fitting successful: {len(newfluxes)} active reactions, biomass={results[strain]['newflux_biomass']:.4f}")
        else:
            print(f"  ✗ Flux fitting failed: {solution.status}")
            results[strain]["newfluxes"] = {}
            results[strain]["newflux_biomass"] = 0
            results[strain]["newflux_status"] = solution.status
    
    except Exception as e:
        print(f"  ✗ Error during flux fitting: {str(e)}")
        import traceback
        traceback.print_exc()
        results[strain]["newfluxes"] = {}
        results[strain]["newflux_biomass"] = 0
        results[strain]["newflux_status"] = "error"

# Save updated results
util.save("ADP1ExpressionAnalysis", results)
print(f"\n✓ Saved updated results with targetflux and newfluxes for all strains")

# %% [markdown]
# ## Generate Outputs
#
# Save results in multiple formats:
# 1. Individual JSON files for each condition
# 2. Summary JSON with metadata
# 3. Multi-sheet Excel workbook
# 4. Escher metabolic maps (HTML)

# %%
# Save individual flux JSON files
print("Saving individual flux files...")
for condition_key, result_data in results.items():
    fluxes = result_data.get("fluxes", {})
    util.save(f"{condition_key}_fluxes", fluxes)
print(f"Saved {len(results)} flux JSON files to datacache/")

# %%
# %run util.py
model = MSModelUtil.from_cobrapy("data/FullyTranslatedPublishedModel.json")
results = util.load("ADP1ExpressionAnalysis")
# Generate Escher maps with "full" map
print("Generating Escher metabolic maps...")
output = util.create_map_html(
    model=model.model if hasattr(model, 'model') else model,
    flux_solution=results["ACN2586"]["fluxes"],
    map_name="full",
    map_json="data/full.json",
    output_file="Test.html",
    title="Test"
)
# Out:
# /Users/chenry/Dropbox/Projects/KBUtilLib/src
# 2025-11-11 14:52:14,037 - __main__.NotebookUtil - INFO - Loaded 0 tokens from /Users/chenry/.tokens
# 2025-11-11 14:52:14,038 - __main__.NotebookUtil - INFO - Loaded kbase tokens from /Users/chenry/.kbase/token
# 2025-11-11 14:52:14,038 - __main__.NotebookUtil - WARNING - Section 'ModelSEEDBiochem' not found in config
# modelseedpy 0.4.2
# cobrakbase 0.4.0
# 2025-11-11 14:52:18,090 - __main__.NotebookUtil - INFO - ModelSEED database loaded from /Users/chenry/Dropbox/Projects/KBUtilLib/src/kbutillib/dependencies/ModelSEEDDatabase
# 2025-11-11 14:52:18,567 - __main__.NotebookUtil - WARNING - BLAST tools not found. Install NCBI BLAST+ to use BLAST functionality. On Ubuntu/Debian: sudo apt-get install ncbi-blast+, On MacOS: brew install blast
# 2025-11-11 14:52:18,568 - __main__.NotebookUtil - INFO - Notebook environment detected
# 2025-11-11 14:52:18,568 - __main__.NotebookUtil - INFO - ArgoGatewayClient initialised | model=gpto3mini env=dev timeout=120.0s url=https://apps-dev.inside.anl.gov/argoapi/api/v1/resource/streamchat/
# 2025-11-11 14:52:18,749 - __main__.NotebookUtil - INFO - Using enhanced arrow visualization with smart defaults
# 2025-11-11 14:52:18,749 - __main__.NotebookUtil - INFO - Generated smart reaction_scale with 5 stops
# 2025-11-11 14:52:18,864 - __main__.NotebookUtil - INFO - Successfully got HTML from builder.save_html()
# 2025-11-11 14:52:18,902 - __main__.NotebookUtil - INFO - Escher map HTML saved to: /Users/chenry/Dropbox/Projects/ADP1Notebooks/notebooks/Test.html
# Generating Escher metabolic maps...

# %%
# %run util.py
# Generate Escher map directly using escher.Builder (first strain only)
import escher
from escher import Builder
import json
import os

# Load model and results
model = MSModelUtil.from_cobrapy("data/FullyTranslatedPublishedModel.json")
results = util.load("ADP1ExpressionAnalysis")
strains = ["ACN2586", "ACN2821", "ACN3015", "ACN3468", "ACN3471", "ACN3474", "ACN3477", "ADP1"]

# Get first strain
strain = strains[0]
print(f"Generating map for {strain}...")

# Get fluxes for this strain
fluxes = results[strain].get("fluxes", {})
if not fluxes:
    print(f"Error: No flux data for {strain}")
else:
    print(f"Found {len(fluxes)} reactions with flux data")
    
    # Load the map JSON file
    map_json_path = "data/full.json"
    if not os.path.exists(map_json_path):
        print(f"Warning: {map_json_path} not found. Trying to use map_name instead.")
        map_json_string = None
        map_name = "full"
    else:
        # Load as dict first, then convert to JSON string (Builder expects string, not dict)
        with open(map_json_path, 'r') as f:
            map_json_dict = json.load(f)
        map_json_string = json.dumps(map_json_dict)  # Convert to JSON string
        map_name = None
        print(f"Loaded map from {map_json_path}")
    
    # Create Builder
    builder = Builder(
        model=model.model,
        map_json=map_json_string if map_json_string else None,
        map_name=map_name if not map_json_string else None,
        reaction_data=fluxes,
        height=800,
        width=1200
    )
    
    # Save HTML file
    output_file = f"nboutput/escher_{strain}_direct.html"
    os.makedirs("nboutput", exist_ok=True)
    builder.save_html(output_file)
    print(f"✓ Created: {output_file}")
# Out:
# 2025-11-07 00:10:26,934 - __main__.NotebookUtil - INFO - Loaded 0 tokens from /Users/chenry/.tokens
# 2025-11-07 00:10:26,935 - __main__.NotebookUtil - INFO - Loaded kbase tokens from /Users/chenry/.kbase/token
# 2025-11-07 00:10:26,936 - __main__.NotebookUtil - WARNING - Section 'ModelSEEDBiochem' not found in config
# 2025-11-07 00:10:26,936 - __main__.NotebookUtil - INFO - ModelSEED database loaded from /Users/chenry/Dropbox/Projects/KBUtilLib/src/kbutillib/dependencies/ModelSEEDDatabase
# /Users/chenry/Dropbox/Projects/KBUtilLib/src
# 2025-11-07 00:10:27,296 - __main__.NotebookUtil - INFO - Notebook environment detected
# 2025-11-07 00:10:27,297 - __main__.NotebookUtil - INFO - ArgoGatewayClient initialised | model=gpto3mini env=dev timeout=120.0s url=https://apps-dev.inside.anl.gov/argoapi/api/v1/resource/streamchat/
# Generating map for ACN2586...
# Found 433 reactions with flux data
# Loaded map from data/full.json
# ✓ Created: nboutput/escher_ACN2586_direct.html
